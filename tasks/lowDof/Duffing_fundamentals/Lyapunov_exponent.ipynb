# %% [markdown]
# # Duffing Lyapunov Experiments
#
# The reusable implementation is in `duffing_lyapunov.py`.
#
# For interactive work in VS Code, use `duffing_lyapunov_experiments.py` and run cells with **Run Current File in Interactive Window**. That script contains the single-run phase/Poincare analysis and the parallel `joblib` frequency/amplitude sweeps.

# %%
# %run duffing_lyapunov_experiments.py
